# %% [markdown]
# <h1>POSTTEST 3 KECERDASAN BUATAN</h1>

# %% [markdown]
# <h2>Import Pandas Package</h2>
# <p>Import pandas sebagai pd</p>
# <p>Dari matplotlib import sebagai plt</p>
# <p>Import seaborn sebagai sns</p>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <h2> Membaca dataset yang telah di download dengan format csv</h2>

# %%
df = pd.read_csv("Indonesia_coronavirus_daily_data.csv")

# %% [markdown]
# <h2>df untuk menampilkan isi yang ada di dalam dataset</h2>

# %%
df
# Out:
#              Date             Province  Daily_Case  Daily_Death  \
# 0      2020-03-01          DKI JAKARTA           2            0
# 1      2020-03-02          DKI JAKARTA           2            0
# 2      2020-03-03          DKI JAKARTA           2            0
# 3      2020-03-04          DKI JAKARTA           2            0
# 4      2020-03-05          DKI JAKARTA           0            1
# ...           ...                  ...         ...          ...
# 17608  2021-08-14  NUSA TENGGARA TIMUR         649           21
# 17609  2021-08-15  NUSA TENGGARA TIMUR         498            7
# 17610  2021-08-16  NUSA TENGGARA TIMUR         438           18
# 17611  2021-08-17  NUSA TENGGARA TIMUR         657           15
# 17612  2021-08-18  NUSA TENGGARA TIMUR         527            8
#
#        Daily_Recovered  Active_Case  Cumulative_Case  Cumulative_Recovered  \
# 0                    0            2                2                     0
# ...

# %% [markdown]
# <h2>Menampilkan type dari atribut yang ada di dalam dataset</h2>

# %%
df.dtypes
# Out:
# Date                      object
# Province                  object
# Daily_Case                 int64
# Daily_Death                int64
# Daily_Recovered            int64
# Active_Case                int64
# Cumulative_Case            int64
# Cumulative_Recovered       int64
# Cumulative_Death           int64
# Cumulative_Active_Case     int64
# dtype: object

# %% [markdown]
# <h2>Menampilkan jumlah isi dari atribut Province</h2>

# %%
df['Province'].value_counts()
# Out:
# JAWA TIMUR                    589
# DKI JAKARTA                   536
# RIAU                          535
# JAWA BARAT                    535
# BANTEN                        533
# JAWA TENGAH                   529
# SULAWESI TENGGARA             527
# BALI                          526
# KALIMANTAN TIMUR              523
# SUMATERA UTARA                522
# DAERAH ISTIMEWA YOGYAKARTA    521
# SULAWESI SELATAN              520
# KEPULAUAN RIAU                518
# MALUKU                        517
# JAMBI                         517
# MALUKU UTARA                  515
# PAPUA                         515
# SUMATERA SELATAN              514
# KALIMANTAN TENGAH             511
# SULAWESI UTARA                511
# ACEH                          511
# SULAWESI TENGAH               511
# LAMPUNG                       511
# SUMATERA BARAT                511
# PAPUA BARAT                   510
# SULAWESI BARAT                509
# KALIMANTAN UTARA              509
# ...

# %% [markdown]
# <h2>Membuat tabel untuk atribut Province dan membuat atribut jumlah untuk atribut di dalamnya</h2>

# %%
labels = df['Province'].value_counts().rename_axis('Province').reset_index(name='Jumlah')
labels
# Out:
#                       Province  Jumlah
# 0                   JAWA TIMUR     589
# 1                  DKI JAKARTA     536
# 2                         RIAU     535
# 3                   JAWA BARAT     535
# 4                       BANTEN     533
# 5                  JAWA TENGAH     529
# 6            SULAWESI TENGGARA     527
# 7                         BALI     526
# 8             KALIMANTAN TIMUR     523
# 9               SUMATERA UTARA     522
# 10  DAERAH ISTIMEWA YOGYAKARTA     521
# 11            SULAWESI SELATAN     520
# 12              KEPULAUAN RIAU     518
# 13                      MALUKU     517
# 14                       JAMBI     517
# 15                MALUKU UTARA     515
# 16                       PAPUA     515
# 17            SUMATERA SELATAN     514
# 18           KALIMANTAN TENGAH     511
# 19              SULAWESI UTARA     511
# 20                        ACEH     511
# 21             SULAWESI TENGAH     511
# 22                     LAMPUNG     511
# ...

# %% [markdown]
# <h2>Membuat grafik pie</h2>

# %%
plt.figure(figsize=(20,20), dpi=400)
plt.pie(df['Province'].value_counts(), labels=labels['Province'], autopct='%.1f%%', startangle=90)
plt.show()

# %% [markdown]
# <h2>Grafik Boxplot </h2>

# %%
sns.boxplot(x= df['Cumulative_Active_Case'], y=df['Province'])
plt.show()

# %% [markdown]
# <h2>Grafik Scatter Plot</h2>

# %%
sns.scatterplot(data = df, x='Cumulative_Active_Case', y = 'Province')
plt.title("Persebaran data ukuran Attack dengan Attribute yang beda")
plt.show()
