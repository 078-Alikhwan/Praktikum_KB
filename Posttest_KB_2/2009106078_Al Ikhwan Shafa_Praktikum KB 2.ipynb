# %% [markdown]
# <h1>Indonesia_coronavirus_daily_data </h1>

# %% [markdown]
# <h3>Import Pandas Package</h3>

# %% [markdown]
# <h5>Import pandas sebagai pd dan df membaca dataset</h5>

# %%
import pandas as pd

# %%
df = pd.read_csv("Indonesia_coronavirus_daily_data.csv")

# %% [markdown]
# <h2>Membaca Dataset</h2>

# %%
df
# Out:
#              Date             Province  Daily_Case  Daily_Death  \
# 0      2020-03-01          DKI JAKARTA           2            0
# 1      2020-03-02          DKI JAKARTA           2            0
# 2      2020-03-03          DKI JAKARTA           2            0
# 3      2020-03-04          DKI JAKARTA           2            0
# 4      2020-03-05          DKI JAKARTA           0            1
# ...           ...                  ...         ...          ...
# 17608  2021-08-14  NUSA TENGGARA TIMUR         649           21
# 17609  2021-08-15  NUSA TENGGARA TIMUR         498            7
# 17610  2021-08-16  NUSA TENGGARA TIMUR         438           18
# 17611  2021-08-17  NUSA TENGGARA TIMUR         657           15
# 17612  2021-08-18  NUSA TENGGARA TIMUR         527            8
#
#        Daily_Recovered  Active_Case  Cumulative_Case  Cumulative_Recovered  \
# 0                    0            2                2                     0
# ...

# %%
df.dtypes
# Out:
# Date                      object
# Province                  object
# Daily_Case                 int64
# Daily_Death                int64
# Daily_Recovered            int64
# Active_Case                int64
# Cumulative_Case            int64
# Cumulative_Recovered       int64
# Cumulative_Death           int64
# Cumulative_Active_Case     int64
# dtype: object

# %% [markdown]
# <h2>Informasi yang didapatkan adalah</h2>
# <p>jumlah record,
#
# nama attribute,
#
# jumlah attribute dengan tipe objek,
#
# jumlah attribute dengan tipe angka,
#
# jumlah attribute yang memiliki nilai null.</p>
#
# <h2>Masukkan informasi di atas dalam dictionary dengan key sesuai nama informasinya. Tampilkan isi dari dictionary tersebut sebagus mungkin.</h2>

# %%
totalRecord = len(df)
namaAttribute = df.columns
jumlahObjek = len(df.select_dtypes(include=['object']).columns)
jumlahAngka = len(df.select_dtypes(include=['int64']).columns)
jumlahNULL = len(df.columns[df.isna().sum() > 0])

dictionary_no1 = {
    "total record": totalRecord,
    "Nama Attribute yang ada": namaAttribute,
    "Jumlah Objek": jumlahObjek,
    "Jumlah Angka": jumlahAngka,
    "Jumlah NULL": jumlahNULL,
}

pd.Series(dictionary_no1)
# Out:
# total record                                                           17613
# Nama Attribute yang ada    Index(['Date', 'Province', 'Daily_Case', 'Dail...
# Jumlah Objek                                                               2
# Jumlah Angka                                                               8
# Jumlah NULL                                                                0
# dtype: object

# %% [markdown]
# <h3>Tampilkan rata-rata, standar deviasi, nilai minimum, nilai maksimum, Q1, Q2, dan Q3 dari attribute bertipe angka.</h3>
# <h4>Tampilkan Nilai rata-rata dengan fungsi mean()</h4>

# %%
df.select_dtypes(include=['int64']).mean()
# Out:
# Daily_Case                  221.893545
# Daily_Death                   6.870039
# Daily_Recovered             195.509964
# Active_Case                  19.513541
# Cumulative_Case           27335.891330
# Cumulative_Recovered      23304.481349
# Cumulative_Death            791.460626
# Cumulative_Active_Case     3239.949356
# dtype: float64

# %% [markdown]
# <h4>Tampilkan Nilai Standar deviasi dengan fungsi std()</h4>

# %%
df.select_dtypes(include=['int64']).std()
# Out:
# Daily_Case                  721.871111
# Daily_Death                  27.146578
# Daily_Recovered             736.091866
# Active_Case                 458.896272
# Cumulative_Case           73651.551064
# Cumulative_Recovered      65493.448680
# Cumulative_Death           2129.488593
# Cumulative_Active_Case     8872.743835
# dtype: float64

# %% [markdown]
# <h4>Tampilkan Nilai Minimum dengan fungsi min()</h4>

# %%
df.select_dtypes(include=['int64']).min()
# Out:
# Daily_Case                    0
# Daily_Death                   0
# Daily_Recovered               0
# Active_Case              -16623
# Cumulative_Case               1
# Cumulative_Recovered          0
# Cumulative_Death              0
# Cumulative_Active_Case    -2228
# dtype: int64

# %% [markdown]
# <h4>Tampilkan Nilai Maksimum dengan fungsi max()</h4>

# %%
df.select_dtypes(include=['int64']).max()
# Out:
# Daily_Case                 14622
# Daily_Death                  544
# Daily_Recovered            20602
# Active_Case                 9540
# Cumulative_Case           842610
# Cumulative_Recovered      820650
# Cumulative_Death           26324
# Cumulative_Active_Case    129731
# dtype: int64

# %% [markdown]
# <h4>Tampilkan Nilai Q1, Q2, dan Q3 dengan fungsi quantile()</h4>

# %%
df.select_dtypes(include=['int64']).quantile([0.25,0.5,0.75])
# Out:
#       Daily_Case  Daily_Death  Daily_Recovered  Active_Case  Cumulative_Case  \
# 0.25         7.0          0.0              3.0         -8.0            867.0
# 0.50        42.0          1.0             27.0          2.0           6526.0
# 0.75       143.0          4.0            119.0         33.0          19635.0
#
#       Cumulative_Recovered  Cumulative_Death  Cumulative_Active_Case
# 0.25                 450.0              25.0                   188.0
# 0.50                5029.0             164.0                   926.0
# 0.75               15631.0             574.0                  2467.0

# %% [markdown]
# <h4>Menampilakn semua sekaligus diatas dengan fungsi .describe()</h4>

# %%
df.describe()
# Out:
#          Daily_Case   Daily_Death  Daily_Recovered   Active_Case  \
# count  17613.000000  17613.000000     17613.000000  17613.000000
# mean     221.893545      6.870039       195.509964     19.513541
# std      721.871111     27.146578       736.091866    458.896272
# min        0.000000      0.000000         0.000000 -16623.000000
# 25%        7.000000      0.000000         3.000000     -8.000000
# 50%       42.000000      1.000000        27.000000      2.000000
# 75%      143.000000      4.000000       119.000000     33.000000
# max    14622.000000    544.000000     20602.000000   9540.000000
#
#        Cumulative_Case  Cumulative_Recovered  Cumulative_Death  \
# count     17613.000000          17613.000000      17613.000000
# mean      27335.891330          23304.481349        791.460626
# std       73651.551064          65493.448680       2129.488593
# min           1.000000              0.000000          0.000000
# ...

# %% [markdown]
# <h4>Tampilkan nilai korelasi attribute bertipe angka.</h4>

# %%
df.select_dtypes(include=['int64']).corr()
# Out:
#                         Daily_Case  Daily_Death  Daily_Recovered  Active_Case  \
# Daily_Case                1.000000     0.668939         0.802706     0.245909
# Daily_Death               0.668939     1.000000         0.655428    -0.058214
# Daily_Recovered           0.802706     0.655428         1.000000    -0.380118
# Active_Case               0.245909    -0.058214        -0.380118     1.000000
# Cumulative_Case           0.754511     0.585646         0.751661    -0.053454
# Cumulative_Recovered      0.712402     0.544240         0.720568    -0.067371
# Cumulative_Death          0.625477     0.784507         0.610207    -0.041298
# Cumulative_Active_Case    0.854452     0.655827         0.774173     0.063495
#
#                         Cumulative_Case  Cumulative_Recovered  \
# Daily_Case                     0.754511              0.712402
# Daily_Death                    0.585646              0.544240
# Daily_Recovered                0.751661              0.720568
# ...

# %% [markdown]
# <h3>Rubah nilai salah satu attribute bertipe angka menjadi dari desimal menjadi bilangan bulat).</h3>
# <h3>Metode [errors='ignore']</h3>

# %%
df["Daily_Case"] = df["Daily_Case"].astype('float64', errors='ignore')
df["Daily_Case"].dtypes
# Out:
# dtype('float64')

# %%
df["Daily_Case"] = df["Daily_Case"].astype('int64', errors='ignore')

# %% [markdown]
# <h4>Metode [fillna function]</h4>

# %%
pd.options.display.float_format = '{:.3f}'.format
df.Daily_Case.astype('float64')
# Out:
# 0         2.000
# 1         2.000
# 2         2.000
# 3         2.000
# 4         0.000
#           ...
# 17608   649.000
# 17609   498.000
# 17610   438.000
# 17611   657.000
# 17612   527.000
# Name: Daily_Case, Length: 17613, dtype: float64

# %% [markdown]
# <h4>Tampilkan 10 record pertama dari attribute bertipe angka.</h4>

# %%
df.select_dtypes(include=['int64']).head(10)
# Out:
#    Daily_Case  Daily_Death  Daily_Recovered  Active_Case  Cumulative_Case  \
# 0           2            0                0            2                2
# 1           2            0                0            2                4
# 2           2            0                0            2                6
# 3           2            0                0            2                8
# 4           0            1                0           -1                8
# 5           0            0                0            0                8
# 6           0            2                0           -2                8
# 7           0            0                0            0                8
# 8           0            1                0           -1                8
# 9           0            0                0            0                8
#
#    Cumulative_Recovered  Cumulative_Death  Cumulative_Active_Case
# 0                     0                 0                       2
# ...

# %% [markdown]
# <h3>Simpan dataset dengan attribute bertipe angka ke dalam file CSV.</h3>

# %%
df.select_dtypes(include=['int64', 'float64']).to_csv("Atribut_Bertipe Angka.csv")
